# %%
print("hello")
# Out:
# hello

# %%
from abc import ABC

# %%
class Animal(ABC):

    @classmethod
    def speak(self):
        pass 


    def jump(self):
        return f"{self.__class__.__name__} is jumping"

# %%
class Dog(Animal):
    pass

# %%
dog= Dog()

# %%
dog.speak()
